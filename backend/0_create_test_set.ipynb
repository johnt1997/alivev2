# %% [markdown]
# # Evaluation Data Generation

# %%
from packages.document_processing import DocumentProcessing
from packages.generate_tests import TestSetPipeline
from packages.globals import CHUNK_SIZE, CHUNK_OVERLAP

# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/johntusha/Downloads/History-Chat-Bot-master/backend/packages/globals.py:8: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   EMBEDDINGS = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME)

# %%
PERSON = "Washington"
LLM_CONFIG = "Local"
SIMPLE = 0.25
REASONING=0.25
MULTI_CONTEXT=0.25
CONDITIONAL=0.25

N_QUESTIONS=1

# %%
split_documents = DocumentProcessing().get_chunked_documents(
        "./data/" + PERSON + "/", chunk_size=1200, chunk_overlap=0, splitter_type="recursive"
    )
# Out:
# [INFO] DocumentProcessing initialized with embeddings type: <class 'langchain_community.embeddings.huggingface.HuggingFaceEmbeddings'>
# [INFO] Loading documents from: ./data/Washington/
# [INFO] Loaded 513 pages/documents.
# [INFO] Chunking documents using strategy: recursive
# [INFO] Splitting with RecursiveCharacterTextSplitter (size: 1200, overlap: 0)
# [INFO] Original document pages: 513, Split into chunks: 1417 (using recursive)

# %%
test_gen = TestSetPipeline(person_name="Washington", llm_model="gpt-4o-mini", testset_size=30)
# Out:
# hallo

# %%
#testset_df = test_gen.generate_testset(documents=split_documents)
from langchain_community.document_loaders import DirectoryLoader

path = "data/Washington"
loader = DirectoryLoader(path, glob="**/*.pdf")
docs = loader.load()
# Out:
# Cannot set gray non-stroke color because /'P0' is an invalid float value
# Cannot set gray non-stroke color because /'P0' is an invalid float value

# %%
#testset_df = test_gen.generate_testset(documents=split_documents)

#import os
#os.environ["OPENAI_API_KEY"] = "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"

from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from ragas.testset import TestsetGenerator

generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=30)

questions = dataset.to_pandas()
# Out:
# ...
# Applying CustomNodeFilter:   0%|          | 0/141 [00:00<?, ?it/s]
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/258 [00:00<?, ?it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Generating Samples:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
import os
from datetime import datetime
person = "Washington"
questions
#timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
if os.path.exists(f"./autogen_questions/{person}") == False:
    os.mkdir(f"./autogen_questions/{person}")
        
questions.to_csv(f"./autogen_questions/{person}/" + "total2" + ".csv", index=False)
questions.to_json(f"./autogen_questions/{person}/" + "total2" + ".json")

# %%
questions
# Out:
#                                            user_input  \
# 0   What happen at Independence National Historica...
# 1   Can you explane the role of Benjamen Franklin ...
# 2   Why Frederick Douglass say Fourth of July is n...
# 3                 What was American Revolution about?
# 4   Who was Nicolas Spencer in relation to Colonel...
# 5      Who was John and what important things he did?
# 6   What is the significance of Mount Vernon in Ge...
# 7   Can you explain the role of George William Fai...
# 8   What were the key events in George Washington'...
# 9   Why Washington sent to Ohio River valley and w...
# 10  Why George Washington warn us about permanent ...
# 11  How did George Washington's early military car...
# 12  How did George Washington's early life and exp...
# 13  How did George Washington's military leadershi...
# 14  How did the Second Continental Congress's adop...
# 15  why the Declaration of Independence was made a...
# ...
